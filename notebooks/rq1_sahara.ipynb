# %%
# %load_ext autoreload
# %autoreload 2

import sys
from tqdm.notebook import tqdm
from time import sleep
sys.path.append('../')
from src.combined import *

# %%
project = 'sahara'

# %% [markdown]
# Load commits and reviewers

# %%
df_commits = pd.read_csv(f'../data/commits/commits_{project}.csv')

# %%
df_reviews = pd.read_csv(f'../data/reviews/reviews_{project}.csv')

# %% [markdown]
# Keep only commits with reviews

# %%
commits_without_reviews = df_commits.loc[~df_commits['hash'].isin(df_reviews['hash']), 'hash'].values

# %%
len(commits_without_reviews)
# Out:
# 202

# %%
df_commits = df_commits.loc[df_commits['hash'].isin(df_reviews['hash'])]

# %%
len(df_commits)
# Out:
# 3164

# %% [markdown]
# Re-format `prior_commits`

# %%
df_commits['prior_commits'] = df_commits['prior_commits'].apply(
    lambda x : [c for c in split_prior_commits(x) if c not in commits_without_reviews]
)

# %% [markdown]
# Join dataframes

# %%
df = df_commits.set_index('hash').join(df_reviews.set_index('hash'), how = 'left')

df = df.reset_index()

# %%
len(df)
# Out:
# 13934

# %%
# Should be 0 since we already removed beforehand
len(df.loc[df['change_id'].isnull()])
# Out:
# 0

# %% [markdown]
# Compute expertise for author and reviewers

# %%
df['pct_prior_commits_author_authored'] = 0
df['pct_prior_commits_author_reviewed'] = 0
df['pct_prior_commits_reviewer_authored'] = 0
df['pct_prior_commits_reviewer_reviewed'] = 0

# %%
with tqdm(total = len(df)) as pbar:
    for idx, row in df.iterrows():
        pbar.set_postfix({'hash' : row['hash'], 'reviewer' : row['reviewer_name']})
        prior_commits = row['prior_commits']
        # No prior commit
        if len(prior_commits) == 0:
            pbar.update(1)
            sleep(0.001)
            continue
        # Initialize counters
        prior_authors_count = Counter()
        prior_reviewers_count = Counter()
        # Iterate through each prior commit
        for prior_commit in prior_commits:
            # Get the author
            prior_author = df_commits.loc[df_commits['hash'] == prior_commit, 'author_name'].values[0]
            # Increment count
            prior_authors_count[prior_author] += 1
            # Get the reviewers
            prior_reviewers = df_reviews.loc[df_reviews['hash'] == prior_commit, 'reviewer_name'].values
            # Increment counts
            for prior_reviewer in prior_reviewers:
                prior_reviewers_count[prior_reviewer] += 1
        # Calculate percentages for the author
        author = row['author_name']
        pct_prior_commits_author_authored = prior_authors_count[author] / len(prior_commits)
        assert 0 <= pct_prior_commits_author_authored <= 1
        pct_prior_commits_author_reviewed = prior_reviewers_count[author] / len(prior_commits)
        assert 0 <= pct_prior_commits_author_reviewed <= 1
        # Calculate percentages for the reviewer
        reviewer = row['reviewer_name']
        pct_prior_commits_reviewer_authored = prior_authors_count[reviewer] / len(prior_commits)
        assert 0 <= pct_prior_commits_reviewer_authored <= 1
        pct_prior_commits_reviewer_reviewed = prior_reviewers_count[reviewer] / len(prior_commits)
        assert 0 <= pct_prior_commits_reviewer_reviewed <= 1
        # Update values
        df.at[idx, 'pct_prior_commits_author_authored'] = pct_prior_commits_author_authored
        df.at[idx, 'pct_prior_commits_author_reviewed'] = pct_prior_commits_author_reviewed
        df.at[idx, 'pct_prior_commits_reviewer_authored'] = pct_prior_commits_reviewer_authored
        df.at[idx, 'pct_prior_commits_reviewer_reviewed'] = pct_prior_commits_reviewer_reviewed
        # Progress bar
        pbar.update(1)
        sleep(0.001)
# Out:
#   0%|          | 0/13934 [00:00<?, ?it/s]

# %%
df = df.drop(columns = ['prior_commits'])

# %% [markdown]
# ## Patches

# %%
df['project'] = 'sahara'

# %%
df['author_is_exp_author'] = df['pct_prior_commits_author_authored'] > 0.05
df['author_is_exp_reviewer'] = df['pct_prior_commits_author_reviewed'] > 0.05

# %%
df['reviewer_is_exp_author'] = df['pct_prior_commits_reviewer_authored'] > 0
df['reviewer_is_exp_reviewer'] = df['pct_prior_commits_reviewer_reviewed'] > 0

# %%
df = df.drop(columns=[
    'pct_prior_commits_author_authored',
    'pct_prior_commits_author_reviewed',
    'pct_prior_commits_reviewer_authored',
    'pct_prior_commits_reviewer_reviewed'
])

# %%
import json

# %%
with open('../data/core_devs.json', 'r') as j:
    CORE_DEVS = json.loads(j.read())

# %%
for idx, row in df.iterrows():
    project = row['project']
    project_core_devs = CORE_DEVS[project]
    author = row['author_name']
    if author in project_core_devs:
        df.at[idx, 'author_is_core'] = True
    else:
        df.at[idx, 'author_is_core'] = False

# %%
df['author_is_core'].value_counts()
# Out:
# False    13595
# True       339
# Name: author_is_core, dtype: int64

# %%
df['reviewer_vote'].value_counts()
# Out:
#  2    6807
#  1    6345
# -1     741
# -2      41
# Name: reviewer_vote, dtype: int64

# %%
df['pos_vote'] = df['reviewer_vote'] > 0

# %%
df['pos_vote'].value_counts()
# Out:
# True     13152
# False      782
# Name: pos_vote, dtype: int64

# %%
binary_cols = [
    'bug_fixing',
    'fix_inducing',
    'author_is_core',
    'reviewer_is_core',
    'pos_vote', 
    'author_is_exp_author',
    'author_is_exp_reviewer',
    'reviewer_is_exp_author',
    'reviewer_is_exp_reviewer'
]

# %%
for c in binary_cols:
    print(df[c].value_counts())
# Out:
# False    7317
# True     6617
# Name: bug_fixing, dtype: int64
# True     7515
# False    6419
# Name: fix_inducing, dtype: int64
# False    13595
# True       339
# Name: author_is_core, dtype: int64
# False    12866
# True      1068
# Name: reviewer_is_core, dtype: int64
# True     13152
# False      782
# Name: pos_vote, dtype: int64
# False    12266
# True      1668
# Name: author_is_exp_author, dtype: int64
# False    12190
# True      1744
# Name: author_is_exp_reviewer, dtype: int64
# False    13520
# True       414
# Name: reviewer_is_exp_author, dtype: int64
# False    10616
# True      3318
# Name: reviewer_is_exp_reviewer, dtype: int64

# %%
for c in binary_cols:
    df[c] = df[c].astype(int)

# %%
for c in binary_cols:
    print(df[c].value_counts())
# Out:
# 0    7317
# 1    6617
# Name: bug_fixing, dtype: int64
# 1    7515
# 0    6419
# Name: fix_inducing, dtype: int64
# 0    13595
# 1      339
# Name: author_is_core, dtype: int64
# 0    12866
# 1     1068
# Name: reviewer_is_core, dtype: int64
# 1    13152
# 0      782
# Name: pos_vote, dtype: int64
# 0    12266
# 1     1668
# Name: author_is_exp_author, dtype: int64
# 0    12190
# 1     1744
# Name: author_is_exp_reviewer, dtype: int64
# 0    13520
# 1      414
# Name: reviewer_is_exp_author, dtype: int64
# 0    10616
# 1     3318
# Name: reviewer_is_exp_reviewer, dtype: int64

# %%
df.describe().T
# Out:
#                                   count         mean          std  min  \
# num_lines_added                 13934.0   190.649778  1224.478776  0.0
# num_lines_deleted               13934.0   143.617052  2684.783651  0.0
# num_lines_of_code               13934.0   830.763026  1797.340454  0.0
# num_file_impacted               13934.0     5.558490    20.527672  0.0
# num_dirs_impacted               13934.0     3.091144     5.201366  0.0
# min_complexity                  13934.0    14.612459    25.260812  0.0
# mean_complexity                 13934.0    25.178680    28.481969  0.0
# max_complexity                  13934.0    43.627673    49.969417  0.0
# entropy                         13934.0     0.461953     0.403031  0.0
# bug_fixing                      13934.0     0.474882     0.499387  0.0
# description_length              13934.0    33.990383    26.385039  5.0
# num_prior_commits               13934.0     4.100904     9.429199  0.0
# avg_prior_age                   13934.0   176.489128   217.859766  0.0
# num_prior_commits_bug_fixing    13934.0     1.609588     4.356669  0.0
# num_future_commits_bug_fixing   13934.0     1.732166     3.449281  0.0
# fix_inducing                    13934.0     0.539328     0.498469  0.0
# reviewer_id                     13934.0  9530.315416  3438.630181  9.0
# reviewer_vote                   13934.0     1.373331     0.767061 -2.0
# reviewer_is_core                13934.0     0.076647     0.266040  0.0
# num_prior_comments              13934.0    14.838668    53.429874  0.0
# pct_prior_comments_by_reviewer  13934.0     0.022814     0.096227  0.0
# num_prior_votes                 13934.0     3.215014     2.597856  0.0
# pct_prior_pos_votes             13934.0     0.707569     0.392431  0.0
# pct_prior_neg_votes             13934.0     0.143658     0.264766  0.0
# pct_prior_pos_votes_core        13934.0     0.064488     0.197372  0.0
# pct_prior_neg_votes_core        13934.0     0.016027     0.116485  0.0
# reviewer_freq                   13934.0     0.414570     0.356789  0.0
# author_is_exp_author            13934.0     0.119707     0.324630  0.0
# author_is_exp_reviewer          13934.0     0.125161     0.330914  0.0
# reviewer_is_exp_author          13934.0     0.029711     0.169796  0.0
# reviewer_is_exp_reviewer        13934.0     0.238123     0.425950  0.0
# author_is_core                  13934.0     0.024329     0.154074  0.0
# pos_vote                        13934.0     0.943878     0.230165  0.0
#
#                                         25%          50%           75%  \
# num_lines_added                    4.000000    19.000000     82.000000
# num_lines_deleted                  1.000000     4.000000     19.750000
# num_lines_of_code                121.000000   328.000000    825.000000
# num_file_impacted                  1.000000     2.000000      5.000000
# num_dirs_impacted                  1.000000     2.000000      3.000000
# min_complexity                     0.000000     5.000000     18.000000
# mean_complexity                    0.000000    18.750000     37.500000
# max_complexity                     0.000000    29.000000     71.000000
# entropy                            0.000000     0.588527      0.840954
# bug_fixing                         0.000000     0.000000      1.000000
# description_length                16.000000    27.000000     42.000000
# num_prior_commits                  1.000000     2.000000      4.000000
# avg_prior_age                     13.000000   106.000000    253.812500
# num_prior_commits_bug_fixing       0.000000     0.000000      2.000000
# num_future_commits_bug_fixing      0.000000     1.000000      2.000000
# fix_inducing                       0.000000     1.000000      1.000000
# reviewer_id                     7125.000000  8091.000000  12038.000000
# reviewer_vote                      1.000000     1.000000      2.000000
# reviewer_is_core                   0.000000     0.000000      0.000000
# num_prior_comments                 3.000000     7.000000     16.000000
# pct_prior_comments_by_reviewer     0.000000     0.000000      0.000000
# num_prior_votes                    1.000000     3.000000      5.000000
# pct_prior_pos_votes                0.500000     1.000000      1.000000
# pct_prior_neg_votes                0.000000     0.000000      0.200000
# pct_prior_pos_votes_core           0.000000     0.000000      0.000000
# pct_prior_neg_votes_core           0.000000     0.000000      0.000000
# reviewer_freq                      0.066436     0.333333      0.756027
# author_is_exp_author               0.000000     0.000000      0.000000
# author_is_exp_reviewer             0.000000     0.000000      0.000000
# reviewer_is_exp_author             0.000000     0.000000      0.000000
# reviewer_is_exp_reviewer           0.000000     0.000000      0.000000
# author_is_core                     0.000000     0.000000      0.000000
# pos_vote                           1.000000     1.000000      1.000000
#
#                                         max
# num_lines_added                  29847.0000
# num_lines_deleted               204063.0000
# num_lines_of_code                30286.0000
# num_file_impacted                  796.0000
# num_dirs_impacted                  172.0000
# min_complexity                     262.0000
# mean_complexity                    262.0000
# max_complexity                     263.0000
# entropy                              1.0000
# bug_fixing                           1.0000
# description_length                 294.0000
# num_prior_commits                  207.0000
# avg_prior_age                     1888.9375
# num_prior_commits_bug_fixing        74.0000
# num_future_commits_bug_fixing       51.0000
# fix_inducing                         1.0000
# reviewer_id                      29051.0000
# reviewer_vote                        2.0000
# reviewer_is_core                     1.0000
# num_prior_comments                1379.0000
# pct_prior_comments_by_reviewer       1.0000
# num_prior_votes                     15.0000
# pct_prior_pos_votes                  1.0000
# pct_prior_neg_votes                  1.0000
# pct_prior_pos_votes_core             1.0000
# pct_prior_neg_votes_core             1.0000
# reviewer_freq                        1.0000
# author_is_exp_author                 1.0000
# author_is_exp_reviewer               1.0000
# reviewer_is_exp_author               1.0000
# reviewer_is_exp_reviewer             1.0000
# author_is_core                       1.0000
# pos_vote                             1.0000

# %%
df.to_csv('../data/rq1/rq1_sahara.csv', index=False)

# %%
num_cols = [
    'min_complexity',
    'mean_complexity',
    'max_complexity',
    'num_prior_votes',
    'num_lines_added',
    'num_lines_deleted',
    'num_lines_of_code',
    'num_dirs_impacted',
    'num_file_impacted',
    'description_length',
    'num_prior_commits',
    'num_prior_comments',
    'num_prior_commits_bug_fixing',
    'num_future_commits_bug_fixing',
    'avg_prior_age'
]

# %%
for c in num_cols:
    df[c] = (df[c] - df[c].min()) / (df[c].max() - df[c].min())

# %%
df.describe().T
# Out:
#                                   count         mean          std  min  \
# num_lines_added                 13934.0     0.006388     0.041025  0.0
# num_lines_deleted               13934.0     0.000704     0.013157  0.0
# num_lines_of_code               13934.0     0.027431     0.059346  0.0
# num_file_impacted               13934.0     0.006983     0.025789  0.0
# num_dirs_impacted               13934.0     0.017972     0.030240  0.0
# min_complexity                  13934.0     0.055773     0.096415  0.0
# mean_complexity                 13934.0     0.096102     0.108710  0.0
# max_complexity                  13934.0     0.165885     0.189998  0.0
# entropy                         13934.0     0.461953     0.403031  0.0
# bug_fixing                      13934.0     0.474882     0.499387  0.0
# description_length              13934.0     0.100313     0.091298  0.0
# num_prior_commits               13934.0     0.019811     0.045552  0.0
# avg_prior_age                   13934.0     0.093433     0.115335  0.0
# num_prior_commits_bug_fixing    13934.0     0.021751     0.058874  0.0
# num_future_commits_bug_fixing   13934.0     0.033964     0.067633  0.0
# fix_inducing                    13934.0     0.539328     0.498469  0.0
# reviewer_id                     13934.0  9530.315416  3438.630181  9.0
# reviewer_vote                   13934.0     1.373331     0.767061 -2.0
# reviewer_is_core                13934.0     0.076647     0.266040  0.0
# num_prior_comments              13934.0     0.010760     0.038745  0.0
# pct_prior_comments_by_reviewer  13934.0     0.022814     0.096227  0.0
# num_prior_votes                 13934.0     0.214334     0.173190  0.0
# pct_prior_pos_votes             13934.0     0.707569     0.392431  0.0
# pct_prior_neg_votes             13934.0     0.143658     0.264766  0.0
# pct_prior_pos_votes_core        13934.0     0.064488     0.197372  0.0
# pct_prior_neg_votes_core        13934.0     0.016027     0.116485  0.0
# reviewer_freq                   13934.0     0.414570     0.356789  0.0
# author_is_exp_author            13934.0     0.119707     0.324630  0.0
# author_is_exp_reviewer          13934.0     0.125161     0.330914  0.0
# reviewer_is_exp_author          13934.0     0.029711     0.169796  0.0
# reviewer_is_exp_reviewer        13934.0     0.238123     0.425950  0.0
# author_is_core                  13934.0     0.024329     0.154074  0.0
# pos_vote                        13934.0     0.943878     0.230165  0.0
#
#                                         25%          50%           75%  \
# num_lines_added                    0.000134     0.000637      0.002747
# num_lines_deleted                  0.000005     0.000020      0.000097
# num_lines_of_code                  0.003995     0.010830      0.027240
# num_file_impacted                  0.001256     0.002513      0.006281
# num_dirs_impacted                  0.005814     0.011628      0.017442
# min_complexity                     0.000000     0.019084      0.068702
# mean_complexity                    0.000000     0.071565      0.143130
# max_complexity                     0.000000     0.110266      0.269962
# entropy                            0.000000     0.588527      0.840954
# bug_fixing                         0.000000     0.000000      1.000000
# description_length                 0.038062     0.076125      0.128028
# num_prior_commits                  0.004831     0.009662      0.019324
# avg_prior_age                      0.006882     0.056116      0.134368
# num_prior_commits_bug_fixing       0.000000     0.000000      0.027027
# num_future_commits_bug_fixing      0.000000     0.019608      0.039216
# fix_inducing                       0.000000     1.000000      1.000000
# reviewer_id                     7125.000000  8091.000000  12038.000000
# reviewer_vote                      1.000000     1.000000      2.000000
# reviewer_is_core                   0.000000     0.000000      0.000000
# num_prior_comments                 0.002175     0.005076      0.011603
# pct_prior_comments_by_reviewer     0.000000     0.000000      0.000000
# num_prior_votes                    0.066667     0.200000      0.333333
# pct_prior_pos_votes                0.500000     1.000000      1.000000
# pct_prior_neg_votes                0.000000     0.000000      0.200000
# pct_prior_pos_votes_core           0.000000     0.000000      0.000000
# pct_prior_neg_votes_core           0.000000     0.000000      0.000000
# reviewer_freq                      0.066436     0.333333      0.756027
# author_is_exp_author               0.000000     0.000000      0.000000
# author_is_exp_reviewer             0.000000     0.000000      0.000000
# reviewer_is_exp_author             0.000000     0.000000      0.000000
# reviewer_is_exp_reviewer           0.000000     0.000000      0.000000
# author_is_core                     0.000000     0.000000      0.000000
# pos_vote                           1.000000     1.000000      1.000000
#
#                                     max
# num_lines_added                     1.0
# num_lines_deleted                   1.0
# num_lines_of_code                   1.0
# num_file_impacted                   1.0
# num_dirs_impacted                   1.0
# min_complexity                      1.0
# mean_complexity                     1.0
# max_complexity                      1.0
# entropy                             1.0
# bug_fixing                          1.0
# description_length                  1.0
# num_prior_commits                   1.0
# avg_prior_age                       1.0
# num_prior_commits_bug_fixing        1.0
# num_future_commits_bug_fixing       1.0
# fix_inducing                        1.0
# reviewer_id                     29051.0
# reviewer_vote                       2.0
# reviewer_is_core                    1.0
# num_prior_comments                  1.0
# pct_prior_comments_by_reviewer      1.0
# num_prior_votes                     1.0
# pct_prior_pos_votes                 1.0
# pct_prior_neg_votes                 1.0
# pct_prior_pos_votes_core            1.0
# pct_prior_neg_votes_core            1.0
# reviewer_freq                       1.0
# author_is_exp_author                1.0
# author_is_exp_reviewer              1.0
# reviewer_is_exp_author              1.0
# reviewer_is_exp_reviewer            1.0
# author_is_core                      1.0
# pos_vote                            1.0

# %%
df.to_csv('../data/rq1/rq1_sahara_norm.csv', index=False)
